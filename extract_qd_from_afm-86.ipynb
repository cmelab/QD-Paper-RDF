# %%
import matplotlib.pyplot as plt
from skimage.exposure import rescale_intensity
from skimage import io, filters, color, measure
from skimage.feature import peak_local_max
from scipy import ndimage 
import numpy as np
import xlrd
import freud.box
from freud import box, density
from scipy import stats
import os
# %matplotlib inline

def get_dots(file,microns=2,compare=False,spacing=40,threshold=.55):
    image = color.rgb2gray(io.imread(file))
    i1 = ndimage.maximum_filter(image,size=spacing,mode='constant')
    i1 = rescale_intensity(i1,in_range=(threshold,1))
    i1 = filters.gaussian(i1)
    coordinates = peak_local_max(i1, min_distance=spacing,indices=False)
    if compare:
        io.imshow(image-coordinates)
    label_img = measure.label(coordinates)
    centroids = []
    for region in measure.regionprops(label_img):
        centroids.append(region.centroid)
    scaled = microns*np.asarray(centroids)/image.shape - [microns/2,microns/2]
    return np.append(scaled,np.zeros((len(scaled),1)),axis=1)

# %%
rdfs = []
L = 2
box = freud.box.Box(L,L,is2D=True)
box.periodic=[True,True,False]
rdf = freud.density.RDF(20,.9,normalize=True)

# %%
dots=get_dots("86/2.6.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.14.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.9.T.tif",compare=True,threshold=.3, spacing=70)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("86/2.7.tiff",compare=True,threshold=.8, spacing=15)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.0.tiff",compare=True,threshold=.6, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.8.T.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("86/2.1.tiff",compare=True,threshold=.3, spacing=15)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.2.tiff",compare=True,threshold=.3, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.3.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.10.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.2.T.tif",compare=True,threshold=.4, spacing=80)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("86/2.4.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.7.T.tif",compare=True,threshold=.4, spacing=80)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("86/2.8.tiff",compare=True,threshold=.5, spacing=15)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("86/2.9.tiff",compare=True,threshold=.4, spacing=20)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-1-2911865e733a>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
rdfs = np.asarray(rdfs)
mean_count = np.mean(rdfs,axis=0)
sem =  stats.sem(rdfs, axis=0, ddof=1)
plt.errorbar(rdf.bin_centers, mean_count, yerr=sem)
plt.xlabel("r (μm)")
plt.ylabel("<g(r)>")
plt.show()

# %%
#87
print(mean_count)
# Out:
# [0.         0.08863588 0.34988597 1.1237397  1.1193427  1.1036669
#  1.0805109  0.97621036 0.9836705  1.055796   0.98059064 0.99840385
#  1.0169265  0.9928013  1.0032728  0.93109936 1.0114532  1.0440224
#  1.0191945  1.0328479 ]
