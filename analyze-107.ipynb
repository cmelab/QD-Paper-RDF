# %%
from qd_rdf import get_dots, data_path, plot_rdf
import numpy as np

# %%
rdfs = []
R = []

# %%
L=5
dots=get_dots2("107/5a.tif",compare=True,microns=L, size=2,spacing=2)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# <ipython-input-1-8f0c6e516059>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))
# 64.36760519038268

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
L=2
dots=get_dots2("107/2a.tif",compare=True, microns =L, size=4,spacing=7)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# <ipython-input-1-8f0c6e516059>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))
# 67.68974434224127

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
dots=get_dots2("107/2b.tif",compare=True, microns =L,size=4, spacing=7)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# <ipython-input-1-8f0c6e516059>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))
# 67.07784709055376

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
L=1
dots=get_dots2("107/1a.tif",compare=True, microns =L,size=8, spacing=10)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# <ipython-input-1-8f0c6e516059>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))
# 53.376051268362374

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
dots=get_dots2("107/1b.tif",compare=True, microns =L, size=8,spacing=10)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# <ipython-input-1-8f0c6e516059>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))
# 53.07448924342752

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
rdfs = np.asarray(rdfs)
mean_count = np.mean(rdfs,axis=0)
sem =  stats.sem(rdfs, axis=0, ddof=1)
r,rdf = plot_rdf(dots,L,plot=False)
plt.errorbar(1000*r/np.mean(R), mean_count, yerr=sem)
#plt.xlabel("r (μm)")
plt.xlabel("r/<R>")
plt.ylabel("<g(r)>")
plt.savefig("M107.png")
np.savetxt("M107.csv",(1000*r/np.mean(R),mean_count,sem),delimiter=',')
plt.show()

# %%
print(R)
print(np.mean(R),np.std(R))
# Out:
# [64.36760519038268, 67.68974434224127, 67.07784709055376, 53.376051268362374, 53.07448924342752]
# 61.11714742699352 6.540693644498621
