# %%
import matplotlib.pyplot as plt
from skimage.exposure import rescale_intensity
from skimage import io, filters, color, measure
from skimage.feature import peak_local_max
from scipy import ndimage 
import numpy as np
import xlrd
import freud.box
from freud import box, density
from scipy import stats
import os
# %matplotlib inline
    
def get_dots2(file,microns=2,compare=False,spacing=5,size=4):
    image = color.rgb2gray(io.imread(file))
    i1 = filters.gaussian(image,sigma=2)
    #i1 = filters.gaussian(i1,sigma=1.5)
    i1 = ndimage.maximum_filter(i1,size=size,mode='constant')
    coordinates = peak_local_max(i1, min_distance=spacing,indices=False)
    if compare:
        #io.imshow(coordinates)
        io.imshow(image -coordinates)
    label_img = measure.label(coordinates)
    centroids = []
    for region in measure.regionprops(label_img):
        centroids.append(region.centroid)
    scaled = microns*np.asarray(centroids)/image.shape - [microns/2,microns/2]
    return np.append(scaled,np.zeros((len(scaled),1)),axis=1)

def plot_rdf(dots,L,plot=True):
    box = freud.box.Box(L,L,is2D=True)
    box.periodic=[True,True,False]
    rdf = freud.density.RDF(20,.49,normalize=True)
    rdf.compute(system=(box,dots),reset=True)
    if plot:
        plt.scatter(rdf.bin_centers, rdf.rdf)
        plt.xlabel("r (μm)")
        plt.ylabel("<g(r)>")
        plt.show()
    return rdf.bin_centers, rdf.rdf

# %%
rdfs = []
R = []

# %%
L=2
dots=get_dots2("raw_samples/156/2a.tif",compare=True,microns=L, size=5,spacing=6)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7df421c3c96d> in <module>
#       1 L=2
# ----> 2 dots=get_dots2("156/2a.tif",compare=True,microns=L, size=5,spacing=6)
#       3 b=1/np.sqrt(len(dots)/(L*1000*1000*L))
#       4 print(b)
#       5 R.append(b)
#
# <ipython-input-1-1fba58893bfd> in get_dots2(file, microns, compare, spacing, size)
#      13
#      14 def get_dots2(file,microns=2,compare=False,spacing=5,size=4):
# ---> 15     image = color.rgb2gray(io.imread(file))
#      16     i1 = filters.gaussian(image,sigma=2)
#      17     #i1 = filters.gaussian(i1,sigma=1.5)
#
# ~/miniconda3/lib/python3.8/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# ~/miniconda3/lib/python3.8/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# ~/miniconda3/lib/python3.8/site-packages/skimage/io/_plugins/tifffile_plugin.py in imread(fname, **kwargs)
#      28         kwargs['key'] = kwargs.pop('img_num')
#      29
# ---> 30     return tifffile_imread(fname, **kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/tifffile/tifffile.py in imread(files, aszarr, **kwargs)
#     769
#     770         if isinstance(files, (str, os.PathLike)) or hasattr(files, 'seek'):
# --> 771             with TiffFile(files, **kwargs_file) as tif:
#     772                 if aszarr:
#     773                     return tif.aszarr(**kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/tifffile/tifffile.py in __init__(self, arg, name, offset, size, mode, _multifile, _useframes, _master, **kwargs)
#    2882                     raise TypeError(f'unexpected keyword argument: {key}')
#    2883
# -> 2884         fh = FileHandle(arg, mode=mode, name=name, offset=offset, size=size)
#    2885         self._fh = fh
#    2886         self._multifile = bool(_multifile)
#
# ~/miniconda3/lib/python3.8/site-packages/tifffile/tifffile.py in __init__(self, file, mode, name, offset, size)
#    8956         self.is_file = None
#    8957         self._lock = NullContext()
# -> 8958         self.open()
#    8959
#    8960     def open(self):
#
# ~/miniconda3/lib/python3.8/site-packages/tifffile/tifffile.py in open(self)
#    8969             self._file = os.path.realpath(self._file)
#    8970             self._dir, self._name = os.path.split(self._file)
# -> 8971             self._fh = open(self._file, self._mode)
#    8972             self._close = True
#    8973             if self._offset is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/KATELYNBOETTCHER/mse150projects/project2/QD-Paper-RDF/156/2a.tif'

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
L=1
dots=get_dots2("156/1a.tif",compare=True, microns =L, size=6,spacing=7)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# 41.73919355648411

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
L=1
dots=get_dots2("156/1b.tif",compare=True, microns =L, size=6,spacing=7)
b=1/np.sqrt(len(dots)/(L*1000*1000*L))
print(b)
R.append(b)
# Out:
# 40.38961958610096

# %%
rdfs.append(plot_rdf(dots,L,plot=True)[1])

# %%
rdfs = np.asarray(rdfs)
mean_count = np.mean(rdfs,axis=0)
sem =  stats.sem(rdfs, axis=0, ddof=1)
r,rdf = plot_rdf(dots,L,plot=False)
plt.errorbar(1000*r/np.mean(R), mean_count, yerr=sem)
#plt.xlabel("r (μm)")
plt.xlabel("r/<R>")
plt.ylabel("<g(r)>")
plt.savefig("M156.png")
np.savetxt("M156.csv",(1000*r/np.mean(R),mean_count,sem),delimiter=',')
plt.show()

# %%
print(R)
print(np.mean(R),np.std(R))
# Out:
# [66.29935441317959, 41.73919355648411, 40.38961958610096]
# 49.47605585192156 11.908620640424143
