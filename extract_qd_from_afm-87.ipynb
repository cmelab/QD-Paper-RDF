# %%
import matplotlib.pyplot as plt
from skimage.exposure import rescale_intensity
from skimage import io, filters, color, measure
from skimage.feature import peak_local_max
from scipy import ndimage 
import numpy as np
import xlrd
import freud.box
from freud import box, density
from scipy import stats
import os
# %matplotlib inline

def get_dots(file,microns=2,compare=False,spacing=40,threshold=.55):
    image = color.rgb2gray(io.imread(file))
    i1 = ndimage.maximum_filter(image,size=spacing,mode='constant')
    i1 = rescale_intensity(i1,in_range=(threshold,1))
    i1 = filters.gaussian(i1)
    coordinates = peak_local_max(i1, min_distance=spacing,indices=False)
    if compare:
        io.imshow(image-coordinates)
    label_img = measure.label(coordinates)
    centroids = []
    for region in measure.regionprops(label_img):
        centroids.append(region.centroid)
    scaled = microns*np.asarray(centroids)/image.shape - [microns/2,microns/2]
    return np.append(scaled,np.zeros((len(scaled),1)),axis=1)
os.listdir("87")
# Out:
# ['29.tif',
#  '.DS_Store',
#  '28.tif',
#  '213.tif',
#  '212.tif',
#  '210.tif',
#  '211.tif',
#  '215.tif',
#  '214.tif',
#  '57.tif',
#  '24.tif',
#  '20.tif',
#  '21.tif',
#  '23.tif']

# %%
rdfs = []
L = 2.0
box = freud.box.Box(L,L,is2D=True)
box.periodic=[True,True,False]
rdf = freud.density.RDF(20,0.9,normalize=True)

# %%
dots=get_dots("87/29.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/28.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/213.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/212.tif",compare=True,threshold=.55, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/210.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/211.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/215.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/214.tif",compare=True,threshold=.6, spacing=40)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/24.tif",compare=True,threshold=.7, spacing=90)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-24-7864c17828ed>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("87/20.tif",compare=True,threshold=.6, spacing=90)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)

# %%
dots=get_dots("87/21.tif",compare=True,threshold=.6, spacing=90)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-24-7864c17828ed>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
dots=get_dots("87/23.tif",compare=True,threshold=.6, spacing=90)
rdf.compute(system=(box,dots),reset=True)
rdfs.append(rdf.rdf)
# Out:
# <ipython-input-24-7864c17828ed>:15: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   image = color.rgb2gray(io.imread(file))

# %%
rdfs = np.asarray(rdfs)
mean_count = np.mean(rdfs,axis=0)
sem =  stats.sem(rdfs, axis=0, ddof=1)
plt.errorbar(rdf.bin_centers, mean_count, yerr=sem)
plt.xlabel("r (μm)")
plt.ylabel("<g(r)>")
plt.show()

# %%
#87
